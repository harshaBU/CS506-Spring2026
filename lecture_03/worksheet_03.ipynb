# %% [markdown]
# # Worksheet 03

# %% [markdown]
# ### Distance & Similarity
#
# a) In the Minkowski distance, describe what the parameters p and d are.

# %% [markdown]
# p decides the type of distance used to compute distance between x and y.
# d is the dimensionality (number of coordinates/features).

# %% [markdown]
# b) In your own words describe the difference between the Euclidean distance and the Manhattan distance.

# %% [markdown]
# Euclidian Distance has a p value of two in the Minkowski Distance formula.  This means it measures the straight line distance between two points while Manhattan distance adds up these two components instead of finding the square root of the sum of the squares.

# %% [markdown]
# Consider A = (0, 0) and B = (1, 1). When:
#
# - p = 1, d(A, B) = 2
# - p = 2, d(A, B) = $\sqrt{2} = 1.41$
# - p = 3, d(A, B) = $2^{1/3} = 1.26$
# - p = 4, d(A, B) = $2^{1/4} = 1.19$
#
# c) Describe what you think distance would look like when p is very large.

# %% [markdown]
# Since the value inside the radical will always be of form (1)^n + (1)^n, therefore the radicant will always be 2.  When you take the nth root of this as n approaches infinity, this distance will approach 1.  I know this distance approaches 1 because the nth root of 2 can be rewritten as 2^(1/n).  And as n approaches infinity, 1/n approaches 0.  Therefore 2^(1/n) approaches 1 as n approaches infinity.

# %% [markdown]
# d) Is the minkowski distance still a distance function when p < 1? Expain why / why not.

# %% [markdown]
# No because the triangle equality rule, one of the criterias for a valid distance function, is not met when p is less than 1.

# %% [markdown]
# e) when would you use cosine similarity over the euclidan distance?

# %% [markdown]
# I would choose to use cosine similarity over the euclidian distance if the scenario entails that direction is more imoprtant than magnitude

# %% [markdown]
# f) what does the jaccard distance account for that the manhattan distance doesn't?

# %% [markdown]
# The jaccard distance accounts for the ratio of the intersection of two variables to the union of the two variables.  Manhattan distance on the other hand simply just adds up the differences; even if X and Y have 10000000 similar binary feature values and 2 different values, it would have the same euclidian distance if X and Y had 2 binary feature values which were both different.
